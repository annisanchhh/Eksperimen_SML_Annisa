# %% [markdown]
# # **1. Perkenalan Dataset**

# %% [markdown]
# Dataset yang digunakan dalam penelitian ini adalah Heart Disease Dataset yang diperoleh dari platform Kaggle. Dataset ini berisi data klinis dan demografis pasien yang bertujuan untuk memprediksi keberadaan penyakit jantung. Fitur-fitur yang tersedia mencakup usia, jenis kelamin, tipe nyeri dada, tekanan darah istirahat, kadar kolesterol, gula darah puasa, hasil elektrokardiografi, detak jantung maksimum, angina akibat aktivitas fisik, serta beberapa indikator klinis lainnya. Label target pada dataset ini bersifat biner, yaitu menunjukkan apakah seorang pasien memiliki penyakit jantung atau tidak, sehingga dataset ini sesuai untuk permasalahan klasifikasi biner dalam machine learning.

# %% [markdown]
# # **2. Import Library**

# %% [markdown]
# Pada tahap ini, Anda perlu mengimpor beberapa pustaka (library) Python yang dibutuhkan untuk analisis data dan pembangunan model machine learning atau deep learning.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler, StandardScaler,LabelEncoder

# %% [markdown]
# # **3. Memuat Dataset**

# %% [markdown]
# Pada tahap ini, Anda perlu memuat dataset ke dalam notebook. Jika dataset dalam format CSV, Anda bisa menggunakan pustaka pandas untuk membacanya. Pastikan untuk mengecek beberapa baris awal dataset untuk memahami strukturnya dan memastikan data telah dimuat dengan benar.
#
# Jika dataset berada di Google Drive, pastikan Anda menghubungkan Google Drive ke Colab terlebih dahulu. Setelah dataset berhasil dimuat, langkah berikutnya adalah memeriksa kesesuaian data dan siap untuk dianalisis lebih lanjut.
#
# Jika dataset berupa unstructured data, silakan sesuaikan dengan format seperti kelas Machine Learning Pengembangan atau Machine Learning Terapan

# %%
import pandas as pd

df = pd.read_csv("../heart_raw/heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**
#
# Pada tahap ini, Anda akan melakukan **Exploratory Data Analysis (EDA)** untuk memahami karakteristik dataset.
#
# Tujuan dari EDA adalah untuk memperoleh wawasan awal yang mendalam mengenai data dan menentukan langkah selanjutnya dalam analisis atau pemodelan.

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Korelasi Antar Fitur")
plt.show()

# %%
df.hist(figsize=(15,12), bins=30, edgecolor="black")
plt.title("Distribusi Fitur Numerik", size=16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(df.sample(200), diag_kind="kde")
plt.suptitle("Pairplot Sampel Data", y=1.02)
plt.show()

# %% [markdown]
# # **5. Data Preprocessing**

# %% [markdown]
# Pada tahap ini, data preprocessing adalah langkah penting untuk memastikan kualitas data sebelum digunakan dalam model machine learning.
#
# Jika Anda menggunakan data teks, data mentah sering kali mengandung nilai kosong, duplikasi, atau rentang nilai yang tidak konsisten, yang dapat memengaruhi kinerja model. Oleh karena itu, proses ini bertujuan untuk membersihkan dan mempersiapkan data agar analisis berjalan optimal.
#
# Berikut adalah tahapan-tahapan yang bisa dilakukan, tetapi **tidak terbatas** pada:
# 1. Menghapus atau Menangani Data Kosong (Missing Values)
# 2. Menghapus Data Duplikat
# 3. Normalisasi atau Standarisasi Fitur
# 4. Deteksi dan Penanganan Outlier
# 5. Encoding Data Kategorikal
# 6. Binning (Pengelompokan Data)
#
# Cukup sesuaikan dengan karakteristik data yang kamu gunakan yah. Khususnya ketika kami menggunakan data tidak terstruktur.

# %%
#Missing Value Analysis
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#menghapus duplikasi data
df.drop_duplicates(inplace=True)

# %%
#normalisasi fitur numerik dan standardisasi
numeric_features = df.select_dtypes(include=[np.number]).columns.tolist()
scaler = StandardScaler()

# %%
#deteksi outlier menggunakan IQR
numeric_cols = df.select_dtypes(include=['int64','float64']).columns

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - (1.5 * IQR)
    upper_bound = Q3 + (1.5 * IQR)
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

df.describe()
# Out:
#               age         sex          cp    trestbps        chol    fbs  \
# count  228.000000  228.000000  228.000000  228.000000  228.000000  228.0
# mean    53.333333    0.675439    0.942982  128.671053  242.372807    0.0
# std      9.229016    0.469241    1.020190   15.349142   44.329827    0.0
# min     29.000000    0.000000    0.000000   94.000000  131.000000    0.0
# 25%     45.000000    0.000000    0.000000  120.000000  209.750000    0.0
# 50%     54.000000    1.000000    1.000000  130.000000  239.000000    0.0
# 75%     60.000000    1.000000    2.000000  140.000000  269.250000    0.0
# max     76.000000    1.000000    3.000000  170.000000  360.000000    0.0
#
#           restecg     thalach       exang     oldpeak       slope         ca  \
# count  228.000000  228.000000  228.000000  228.000000  228.000000  228.00000
# mean     0.548246  151.070175    0.315789    0.946053    1.451754    0.47807
# std      0.516125   22.492963    0.465852    1.035422    0.587945    0.69893
# ...

# %%
#penanganan outlier dengan winsorizing
from scipy.stats.mstats import winsorize    
for col in numeric_cols:
    df[col] = winsorize(df[col], limits=[0.05, 0.05])

# %%
#label encoding 
# Pilih fitur
fitur_1 = 'age'
fitur_2 = 'chol'

# BINNING AGE
bins_age = [0, 40, 50, 60, float('inf')]
labels_age = ['Sangat Muda', 'Dewasa Awal', 'Dewasa', 'Lansia']

df['age_Bin'] = pd.cut(df[fitur_1], bins=bins_age, labels=labels_age)

# BINNING CHOLESTEROL
bins_chol = [0, 200, 240, 300, float('inf')]
labels_chol = ['Normal', 'Borderline', 'Tinggi', 'Sangat Tinggi']

df['chol_Bin'] = pd.cut(df[fitur_2], bins=bins_chol, labels=labels_chol)

# ENCODING HASIL BINNING
le = LabelEncoder()

df['age_Bin_enc'] = le.fit_transform(df['age_Bin'])
df['chol_Bin_enc'] = le.fit_transform(df['chol_Bin'])

# Tampilkan hasil
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 2   67    1   0       145   175    0        1      125      1      2.6      1
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 5   58    0   0       105   248    0        0      122      0      1.0      1
# 7   55    1   0       155   289    0        0      145      1      0.8      1
#
#    ca  thal  target age_Bin    chol_Bin  age_Bin_enc  chol_Bin_enc
# 0   2     3       0  Dewasa  Borderline            0             0
# 2   0     3       0  Lansia      Normal            2             1
# 3   1     3       0  Lansia  Borderline            2             0
# 5   0     2       1  Dewasa      Tinggi            0             3
# 7   1     3       0  Dewasa      Tinggi            0             3

# %%
# BINNING AGE (NUMERIK)
bins_age = [0, 40, 50, 60, float('inf')]
df['age_Bin'] = pd.cut(
    df['age'],
    bins=bins_age,
    labels=False
)

# BINNING CHOLESTEROL (NUMERIK)
bins_chol = [0, 200, 240, 300, float('inf')]
df['chol_Bin'] = pd.cut(
    df['chol'],
    bins=bins_chol,
    labels=False
)

# Tampilkan hasil
df[['age', 'age_Bin', 'chol', 'chol_Bin']].head()
# Out:
#    age  age_Bin  chol  chol_Bin
# 0   52        2   212         1
# 2   67        3   175         0
# 3   61        3   203         1
# 5   58        2   248         2
# 7   55        2   289         2

# %%
import pandas as pd
from Automate_Annisa import preprocess_heart_data

df = pd.read_csv("../heart_raw/heart.csv")
df_ready = preprocess_heart_data(df)
# Out:
# ✅ SAVED TO: d:\Kuliah\bootcamp\bootcamp DICODING\Eksperimen_SML_Annisa\preprocessing\heart_preprocessing.csv
